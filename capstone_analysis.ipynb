# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx' )

# %%
df=df.drop([186])

# %%
df.head()
# Out:
#    CASE NO.  Gender   Age  Height(cm)  Weight(kg)  FVC(L)   FVC PRED%  \
# 0    1001.0    Male  21.0       178.0        55.0   4.690    0.873891
# 1    1002.0  Female  28.0       152.0        48.0   2.220    0.712543
# 2    1003.0  Female  29.0       166.0        50.0   3.365    0.907057
# 3    1004.0    Male  24.0       172.0        80.0   4.010    0.811216
# 4    1005.0    Male  25.0       182.0        74.0   4.540    0.826476
#
#    FEV1(L)  FEV1 PRED%  FEV1/FVC(%)  ...         Mode_of_travel_at_home  \
# 0     4.66    1.023052    99.360336  ...                        Walking
# 1     1.69    0.625000    76.313229  ...                        Walking
# 2     3.25    1.005569    96.431618  ...                        Cycling
# 3     3.28    0.779097    81.795509  ...  Bus/ Car/ Other motor vehicle
# 4     3.97    0.860985    87.444931  ...  Bus/ Car/ Other motor vehicle
#
#    Average_students_present_during_class_in_classroom  \
# 0                                               20.0
# ...

# %%
df['Home_location'].mode()
# Out:
# 0    Away from road
# Name: Home_location, dtype: object

# %%
df['Home_location'].fillna('Away from road', inplace=True)

# %%
df['Do_you_smoke'].mode()
# Out:
# 0    No
# Name: Do_you_smoke, dtype: object

# %%
df['Do_you_smoke'].fillna('No', inplace=True)

# %%
df['Any_of_your_family_member_smokes_or_not'].mode()
# Out:
# 0    No
# Name: Any_of_your_family_member_smokes_or_not, dtype: object

# %%
df['Any_of_your_family_member_smokes_or_not'].fillna('No', inplace=True)

# %%
df['Flooring_material_in_home'].mode()
# Out:
# 0    Tiles
# Name: Flooring_material_in_home, dtype: object

# %%
df['Flooring_material_in_home'].fillna('Tiles', inplace=True)

# %%
df['Type_of_fuel_used_at_home'].mode()
# Out:
# 0    Natural gas
# Name: Type_of_fuel_used_at_home, dtype: object

# %%
df['Do_you_smoke'].fillna('Natural gas', inplace=True)

# %%
df['Use_of_insecticides _or_pesticides'].mode()
# Out:
# 0    No
# Name: Use_of_insecticides _or_pesticides, dtype: object

# %%
df['Use_of_insecticides _or_pesticides'].fillna('No', inplace=True)

# %%
df['Do_yo_use_exhaust_fan_in_kitchen'].mode()
# Out:
# 0    Yes
# Name: Do_yo_use_exhaust_fan_in_kitchen, dtype: object

# %%
df['Do_yo_use_exhaust_fan_in_kitchen'].fillna('Yes', inplace=True)

# %%
df['Use_of_exhaust_in_kitchen'].mode()
# Out:
# 0    everyday
# Name: Use_of_exhaust_in_kitchen, dtype: object

# %%
df['Use_of_exhaust_in_kitchen'].fillna('everyday', inplace=True)

# %%
df['Ventilation_status_in_home'].mode()
# Out:
# 0    Windows mostly open
# Name: Ventilation_status_in_home, dtype: object

# %%
df['Ventilation_status_in_home'].fillna('Windows mostly open', inplace=True)

# %%
df['Presence_of_industries_factories_or_construction_activities_nearby_your_home'].mode()
# Out:
# 0    No
# Name: Presence_of_industries_factories_or_construction_activities_nearby_your_home, dtype: object

# %%
df['Presence_of_industries_factories_or_construction_activities_nearby_your_home'].fillna('No', inplace=True)

# %%
df['Mode_of_travel_at_home'].mode()
# Out:
# 0    Bus/ Car/ Other motor vehicle
# Name: Mode_of_travel_at_home, dtype: object

# %%
df['Mode_of_travel_at_home'].fillna(dfg, inplace=True)

# %%
df['How_often_do_you_exercise'].mode()
# Out:
# 0    Hardly
# Name: How_often_do_you_exercise, dtype: object

# %%
df['How_often_do_you_exercise'].fillna('Hardly', inplace=True)

# %%
df['Mode_of_travel_in_college'].mode()
# Out:
# 0    Walking
# Name: Mode_of_travel_in_college, dtype: object

# %%
df['Mode_of_travel_in_college'].fillna('Walking', inplace=True)

# %%
df['Ventilation_status_in_hostels'].mode()
# Out:
# 0    Windows mostly open
# Name: Ventilation_status_in_hostels, dtype: object

# %%
df['Ventilation_status_in_hostels'].fillna('Windows mostly open', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 36 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   CASE NO.                                                                      186 non-null    float64
#  1   Gender                                                                        186 non-null    object
#  2   Age                                                                           186 non-null    float64
#  3   Height(cm)                                                                    186 non-null    float64
#  4   Weight(kg)                                                                    186 non-null    float64
#  5   FVC(L)                                                                        186 non-null    float64
# ...

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [raw]
# FEV1/FVC(%) and Home location

# %%
import seaborn as sns

# %%
sns.barplot(df['FEV1/FVC(%)'],df['Home_location'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Home_location'>

# %%
sns.scatterplot(df['FEV1/FVC(%)'],df['No_of_rooms_in_home'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='No_of_rooms_in_home'>

# %%
sns.barplot(df['FEV1/FVC(%)'],df['Do_you_smoke'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Do_you_smoke'>

# %%
sns.barplot(df['FEV1/FVC(%)'],df['Any_of_your_family_member_smokes_or_not'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Any_of_your_family_member_smokes_or_not'>

# %%
 sns.barplot(df['FEV1/FVC(%)'],df['Flooring_material_in_home'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Flooring_material_in_home'>

# %%
sns.barplot(df['FEV1/FVC(%)'],df['Type_of_fuel_used_at_home'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Type_of_fuel_used_at_home'>

# %%
 sns.scatterplot(df['FEV1/FVC(%)'],df['No_of_occupants_in_home'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='No_of_occupants_in_home'>

# %%
  sns.scatterplot(df['FEV1/FVC(%)'],df['How_long_is_fuel_used_for_cooking_in_hours_day'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='How_long_is_fuel_used_for_cooking_in_hours_day'>

# %%
 sns.barplot(df['FEV1/FVC(%)'],df['Use_of_insecticides _or_pesticides'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Use_of_insecticides _or_pesticides'>

# %%
sns.barplot(df['FEV1/FVC(%)'],df['Do_yo_use_exhaust_fan_in_kitchen'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Do_yo_use_exhaust_fan_in_kitchen'>

# %%
sns.barplot(df['FEV1/FVC(%)'],df['Use_of_exhaust_in_kitchen'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Use_of_exhaust_in_kitchen'>

# %%
 sns.barplot(df['FEV1/FVC(%)'],df['Ventilation_status_in_home'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Ventilation_status_in_home'>

# %%
 sns.barplot(df['FEV1/FVC(%)'],df['Presence_of_industries_factories_or_construction_activities_nearby_your_home'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Presence_of_industries_factories_or_construction_activities_nearby_your_home'>

# %%
 sns.barplot(df['FEV1/FVC(%)'],df['Mode_of_travel_at_home'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Mode_of_travel_at_home'>

# %%
   sns.scatterplot(df['FEV1/FVC(%)'],df['Average_students_present_during_class_in_classroom'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Average_students_present_during_class_in_classroom'>

# %%
 sns.barplot(df['FEV1/FVC(%)'],df['How_often_do_you_exercise'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='How_often_do_you_exercise'>

# %%
  sns.barplot(df['FEV1/FVC(%)'],df['Mode_of_travel_in_college'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Mode_of_travel_in_college'>

# %%
sns.scatterplot(df['FEV1/FVC(%)'],df['Average_time_spend_in_hours_day_in_canteen'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Average_time_spend_in_hours_day_in_canteen'>

# %%
sns.scatterplot(df['FEV1/FVC(%)'],df['Average_time_spend_in_hours_day_in_playground'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Average_time_spend_in_hours_day_in_playground'>

# %%
sns.scatterplot(df['FEV1/FVC(%)'],df['Average_time_spend_in_hours_day_in_classroom'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Average_time_spend_in_hours_day_in_classroom'>

# %%
sns.scatterplot(df['FEV1/FVC(%)'],df['Average_time_spend_ in_hours_day_in_hostel'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Average_time_spend_ in_hours_day_in_hostel'>

# %%
sns.scatterplot(df['FEV1/FVC(%)'],df['Average_time_spend_in_hours_day_in_labs'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Average_time_spend_in_hours_day_in_labs'>

# %%
sns.barplot(df['FEV1/FVC(%)'],df['Ventilation_status_in_hostels'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Ventilation_status_in_hostels'>

# %%
sns.scatterplot(df['FEV1/FVC(%)'],df['Age'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FEV1/FVC(%)', ylabel='Age'>

# %%
sns.pairplot(df)
